# %%
import numpy as np
from tqdm import tqdm
tqdm.pandas()
from matchms import Spectrum
from matchms.exporting import save_as_mgf
from pathlib import Path
import massspecgym.utils as utils

# %%
df = utils.load_massspecgym()
df
# Out:
#                                                                     mzs  \
# identifier
# MassSpecGymID0000001  [91.0542, 125.0233, 154.0499, 155.0577, 185.09...
# MassSpecGymID0000002  [91.0542, 125.0233, 155.0577, 185.0961, 229.08...
# MassSpecGymID0000003  [69.0343, 91.0542, 125.0233, 127.039, 153.0699...
# MassSpecGymID0000004  [69.0343, 91.0542, 110.06, 111.0441, 112.0393,...
# MassSpecGymID0000005  [91.0542, 125.0233, 185.0961, 229.0859, 246.11...
# ...                                                                 ...
# MassSpecGymID0414168  [55.054474, 58.029369, 58.065601, 59.049339, 6...
# MassSpecGymID0414171  [72.043739, 86.060242, 98.058304, 99.0634, 126...
# MassSpecGymID0414172  [72.080132, 102.233917, 113.082344, 113.121498...
# MassSpecGymID0414173  [55.053627, 56.455425, 58.065819, 67.053543, 8...
# MassSpecGymID0414174  [55.055058, 56.049213, 57.05315, 58.064835, 58...
#
#                                                             intensities  \
# identifier
# MassSpecGymID0000001  [0.24524524524524524, 1.0, 0.08008008008008008...
# MassSpecGymID0000002  [0.0990990990990991, 0.28128128128128127, 0.04...
# MassSpecGymID0000003  [0.03403403403403404, 0.31431431431431434, 1.0...
# MassSpecGymID0000004  [0.17917917917917917, 0.47347347347347346, 0.0...
# MassSpecGymID0000005  [0.07807807807807808, 0.1841841841841842, 0.03...
# ...                                                                 ...
# MassSpecGymID0414168  [0.0004935684823754727, 0.00012405427491363124...
# MassSpecGymID0414171  [0.0019527744563354998, 0.0016939927337585416,...
# MassSpecGymID0414172  [0.021173783463613503, 0.007516001055215398, 0...
# MassSpecGymID0414173  [0.031731527156456024, 0.017878400151027027, 0...
# MassSpecGymID0414174  [0.1514287137530871, 0.09596071713375486, 0.06...
#
#                                                                   inchi  \
# identifier
# MassSpecGymID0000001  InChI=1S/C16H17NO4/c1-11(18)17-14(8-12-6-4-3-5...
# MassSpecGymID0000002  InChI=1S/C16H17NO4/c1-11(18)17-14(8-12-6-4-3-5...
# MassSpecGymID0000003  InChI=1S/C16H17NO4/c1-11(18)17-14(8-12-6-4-3-5...
# MassSpecGymID0000004  InChI=1S/C16H17NO4/c1-11(18)17-14(8-12-6-4-3-5...
# MassSpecGymID0000005  InChI=1S/C16H17NO4/c1-11(18)17-14(8-12-6-4-3-5...
# ...                                                                 ...
# MassSpecGymID0414168  InChI=1S/C46H77NO17/c1-13-33-30(22-58-45-42(57...
# MassSpecGymID0414171  InChI=1S/C22H23ClN2O8/c1-21(32)7-6-8-15(25(2)3...
# MassSpecGymID0414172  InChI=1S/C21H43N5O7/c1-9(25-3)13-6-5-10(22)19(...
# MassSpecGymID0414173  InChI=1S/C21H43N5O7/c1-9(25-3)13-6-5-10(22)19(...
# MassSpecGymID0414174  InChI=1S/C21H43N5O7/c1-9(25-3)13-6-5-10(22)19(...
#
#                             inchikey  precursor_mz  adduct  parent_mass  \
# identifier
# MassSpecGymID0000001  VFMQMACUYWGDOJ      288.1225  [M+H]+   287.115224
# MassSpecGymID0000002  VFMQMACUYWGDOJ      288.1225  [M+H]+   287.115224
# MassSpecGymID0000003  VFMQMACUYWGDOJ      288.1225  [M+H]+   287.115224
# MassSpecGymID0000004  VFMQMACUYWGDOJ      288.1225  [M+H]+   287.115224
# MassSpecGymID0000005  VFMQMACUYWGDOJ      288.1225  [M+H]+   287.115224
# ...                              ...           ...     ...          ...
# MassSpecGymID0414168  WBPYTXDJUQJLPQ      916.5290  [M+H]+   915.521724
# MassSpecGymID0414171  DHPRQBPJLMKORJ      479.1230  [M+H]+   478.115724
# MassSpecGymID0414172  CEAZRRDELHUEMR      478.3250  [M+H]+   477.317724
# MassSpecGymID0414173  CEAZRRDELHUEMR      478.3250  [M+H]+   477.317724
# MassSpecGymID0414174  CEAZRRDELHUEMR      478.3250  [M+H]+   477.317724
#
#                            formula precursor_formula instrument_type  \
# identifier
# MassSpecGymID0000001     C16H17NO4         C16H18NO4        Orbitrap
# MassSpecGymID0000002     C16H17NO4         C16H18NO4        Orbitrap
# MassSpecGymID0000003     C16H17NO4         C16H18NO4        Orbitrap
# MassSpecGymID0000004     C16H17NO4         C16H18NO4        Orbitrap
# MassSpecGymID0000005     C16H17NO4         C16H18NO4        Orbitrap
# ...                            ...               ...             ...
# MassSpecGymID0414168    C46H77NO17        C46H78NO17            QTOF
# MassSpecGymID0414171  C22H23ClN2O8      C22H24ClN2O8            QTOF
# MassSpecGymID0414172    C21H43N5O7        C21H44N5O7            QTOF
# MassSpecGymID0414173    C21H43N5O7        C21H44N5O7            QTOF
# MassSpecGymID0414174    C21H43N5O7        C21H44N5O7            QTOF
#
#                       collision_energy  \
# identifier
# MassSpecGymID0000001              30.0
# MassSpecGymID0000002              20.0
# MassSpecGymID0000003              40.0
# MassSpecGymID0000004              55.0
# MassSpecGymID0000005              10.0
# ...                                ...
# MassSpecGymID0414168               NaN
# MassSpecGymID0414171               NaN
# MassSpecGymID0414172               NaN
# MassSpecGymID0414173               NaN
# MassSpecGymID0414174               NaN
#
#                                                                  smiles  \
# identifier
# MassSpecGymID0000001      CC(=O)N[C@@H](CC1=CC=CC=C1)C2=CC(=CC(=O)O2)OC
# MassSpecGymID0000002      CC(=O)N[C@@H](CC1=CC=CC=C1)C2=CC(=CC(=O)O2)OC
# MassSpecGymID0000003      CC(=O)N[C@@H](CC1=CC=CC=C1)C2=CC(=CC(=O)O2)OC
# MassSpecGymID0000004      CC(=O)N[C@@H](CC1=CC=CC=C1)C2=CC(=CC(=O)O2)OC
# MassSpecGymID0000005      CC(=O)N[C@@H](CC1=CC=CC=C1)C2=CC(=CC(=O)O2)OC
# ...                                                                 ...
# MassSpecGymID0414168  CC[C@@H]1[C@H](/C=C(/C=C\C(=O)[C@@H](C[C@@H]([...
# MassSpecGymID0414171  C[C@@]1([C@H]2C[C@H]3[C@@H](C(=O)C(=C([C@]3(C(...
# MassSpecGymID0414172  C[C@H]([C@@H]1CC[C@H]([C@H](O1)O[C@@H]2[C@H](C...
# MassSpecGymID0414173  C[C@H]([C@@H]1CC[C@H]([C@H](O1)O[C@@H]2[C@H](C...
# MassSpecGymID0414174  C[C@H]([C@@H]1CC[C@H]([C@H](O1)O[C@@H]2[C@H](C...
#
#                        fold  simulation_challenge
# identifier
# MassSpecGymID0000001  train                  True
# MassSpecGymID0000002  train                  True
# MassSpecGymID0000003  train                  True
# MassSpecGymID0000004  train                  True
# MassSpecGymID0000005  train                  True
# ...                     ...                   ...
# MassSpecGymID0414168    val                 False
# MassSpecGymID0414171   test                 False
# MassSpecGymID0414172    val                 False
# MassSpecGymID0414173    val                 False
# MassSpecGymID0414174    val                 False
#
# [231104 rows x 14 columns]

# %% [markdown]
# ### Convert final dataset to `.mgf`

# %%
spectra = []
for i, row in tqdm(df.iterrows(), total=len(df)):
    spec = Spectrum(
        mz=row['mzs'],
        intensities=row['intensities'],
        metadata={k: v for k, v in row.items() if k not in ['mzs', 'intensities']}
    )
    spectra.append(spec)
save_as_mgf(spectra, '../../data/data/auxiliary/MassSpecGym.mgf')
# Out:
# 100%|██████████| 231104/231104 [00:22<00:00, 10440.68it/s]

# %% [markdown]
# ### Convert final dataset to `.ms` files
# The cell below is copypasted from https://github.com/samgoldman97/mist/blob/4c23d34fc82425ad5474a53e10b4622dcdbca479/src/mist/utils/parse_utils.py#L71

# %%
from typing import List, Tuple
import numpy as np

def spec_to_ms_str(
    spec: List[Tuple[str, np.ndarray]], essential_keys: dict, comments: dict = {}
) -> str:
    """spec_to_ms_str.

    Turn spec ars and info dicts into str for output file


    Args:
        spec (List[Tuple[str, np.ndarray]]): spec
        essential_keys (dict): essential_keys
        comments (dict): comments

    Returns:
        str:
    """

    def pair_rows(rows):
        return "\n".join([f"{i} {j}" for i, j in rows])

    header = "\n".join(f">{k} {v}" for k, v in essential_keys.items())
    # comments = "\n".join(f"#{k} {v}" for k, v in essential_keys.items())
    spec_strs = [f">{name}\n{pair_rows(ar)}" for name, ar in spec]
    spec_str = "\n\n".join(spec_strs)
    output = f"{header}\n\n{spec_str}"
    return output

# %%
tgt_dir = Path('../../data/data/auxiliary')
(tgt_dir / 'MassSpecGym_ms_files' / 'spec_files').mkdir(exist_ok=True, parents=True)
(tgt_dir / 'MassSpecGym_ms_files' / 'splits').mkdir(exist_ok=True, parents=True)

# %%
for i, row in tqdm(df.iterrows()):
    spec = np.stack([
        row['mzs'],
        row['intensities']
    ]).T

    ms_str = spec_to_ms_str(
        [('ms2peaks', spec)],
        essential_keys={
            'compound': i,
            'formula': row['formula'],
            'parentmass': row['parent_mass'],
            'ionization': '[M + H]+' if row['adduct'] == '[M+H]+' else '[M + Na]+',
            'InChi': row['inchi'],
            'InChIKey': row['inchikey'],
        },
    )

    with open(tgt_dir / 'MassSpecGym_ms_files' / 'spec_files' / f"{i}.ms", "w") as f:
        f.write(ms_str)
# Out:
# 231104it [00:46, 5018.11it/s]

# %%
df_split = df.reset_index()[['identifier', 'fold']]
df_split = df_split.rename(columns={'identifier': 'name'})
df_split.to_csv(tgt_dir / 'MassSpecGym_ms_files' / 'splits' / 'split.csv', index=False)
